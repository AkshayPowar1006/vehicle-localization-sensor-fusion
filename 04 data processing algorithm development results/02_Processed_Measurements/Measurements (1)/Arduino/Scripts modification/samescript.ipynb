# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon
from math import sin, cos, sqrt, atan2, radians
import pyproj
from datetime import datetime

# %%
dfarduino = pd.read_csv('GPSLOG22.csv')

# %%
dfgps1 = dfarduino[dfarduino["GPS"]=="GPS1"]
dfgps2 = dfarduino[dfarduino["GPS"]=="GPS2"]
dfgps3 = dfarduino[dfarduino["GPS"]=="GPS2"]

# %%
#dfgps1.loc[:,"Time"]  = pd.to_datetime(dfgps1["Time"], format=')
dfgps1.loc[:,'Time'] = pd.to_datetime(dfgps1.loc[:,'Time'], format='%H:%M:%S')
# Out:
# C:\Users\Z0168020\AppData\Local\Temp\ipykernel_22228\96484375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgps1.loc[:,'Time'] = pd.to_datetime(dfgps1.loc[:,'Time'], format='%H:%M:%S')

# %%
dfgps1["Time"][3]-dfgps1["Time"][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22228\1349814439.py in <module>
# ----> 1 dfgps1["Time"][3]-dfgps1["Time"][1]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
dfgps1[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfarduino.tail()
# Out:
#        GPS   Latitude  Longitude  Altitude       Date     Time
# 8583  GPS3  48.781291  11.476137     389.6  28-3-2023  10:58:57
# 8584  GPS1  48.781341  11.475961     383.2  28-3-2023  10:58:57
# 8585  GPS2  48.781303  11.476056     393.0  28-3-2023  10:58:57
# 8586  GPS3  48.781291  11.476137     389.6  28-3-2023  10:58:57
# 8587  GPS1  48.781341  11.475961     383.2  28-3-2023  10:58:57
